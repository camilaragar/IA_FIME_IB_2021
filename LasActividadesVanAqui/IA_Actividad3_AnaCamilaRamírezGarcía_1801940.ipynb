# %% [markdown]
# Actividad 3
#
# Ejercicios Introducción Python, 2da parte
#
# Ana Camila Ramírez García 1801940
#
# Inteligencia Artificial y Redes Neuronales
#
# Martes N4

# %% [markdown]
# **Ejercicio 1.1**
#
# Piensa en 7 comidas diferente que te gusten. Implementa un programa que pregunte por las 7 comidas, las almacene en una lista y que posteriermente imprima cada una de ellas utilizando uno de los ciclos comentados en clase.

# %%
# se piden los datos de las 7 comidas favoritas y se guardan en la lista titulada comidas
listacomida = []
#se empieza un ciclo for para almacenar las comidas siete veces
for x in range (7): 
  pregunta = str ( input("¿Cual es su comida favorita?: "))
#ahora concatenamos las respuestas de la pregunta en la lista que inicializamos al principio titulada listacomida
  listacomida.append(pregunta)
#al último, imprimimos la lista de las comidas

print("Tus 7 comidas favoritas son: ", listacomida)
# Out:
# ¿Cual es su comida favorita?: tacos
# ¿Cual es su comida favorita?: cereal
# ¿Cual es su comida favorita?: carne
# ¿Cual es su comida favorita?: pollo
# ¿Cual es su comida favorita?: pizza
# ¿Cual es su comida favorita?: ensalada
# ¿Cual es su comida favorita?: hamburguesa
# Tus 7 comidas favoritas son:  ['tacos', 'cereal', 'carne', 'pollo', 'pizza', 'ensalada', 'hamburguesa']

# %% [markdown]
# **1.2**
#
# Modifica el ejercicio 1.1 para que imprima cada una de las comidas favoritas junto con una oracición inicial: "Una de mis comidas favoritas es [comida1]".

# %%
# se piden los datos de las 7 comidas favoritas y se guardan en la lista titulada comidas
listacomida = []
#se empieza un ciclo for para almacenar las comidas siete veces
for x in range (7): 
  pregunta = str ( input("¿Cual es su comida favorita?: "))
#ahora concatenamos las respuestas de la pregunta en la lista que inicializamos al principio titulada listacomida
  listacomida.append(pregunta)
#al último, imprimimos la lista de las comidas
  print("Una de mis comidas favoritas es: ", listacomida[x])
# Out:
# ¿Cual es su comida favorita?: pescado
# Una de mis comidas favoritas es:  pescado
# ¿Cual es su comida favorita?: pollo
# Una de mis comidas favoritas es:  pollo
# ¿Cual es su comida favorita?: carne
# Una de mis comidas favoritas es:  carne
# ¿Cual es su comida favorita?: atún
# Una de mis comidas favoritas es:  atún
# ¿Cual es su comida favorita?: brócoli
# Una de mis comidas favoritas es:  brócoli
# ¿Cual es su comida favorita?: pizza
# Una de mis comidas favoritas es:  pizza
# ¿Cual es su comida favorita?: cereal
# Una de mis comidas favoritas es:  cereal

# %% [markdown]
# **Ejercicio 2**
#
# Crear un juego de piedra, papel o tijera de dos jugadores. El programa preguntará por la opción del jugador 1 y la opción del jugador 2 y dará como resultado quien ganó el juego.

# %%
#primero le pedimos la opcion a elegir a cada jugador, y  lo almacenamos en la variable respectiva
jugador1 = input("jugador 1: elija una opcion- [piedra, papel. tijera]: ")
jugador2 = input("jugador 2: elija una opcion- [piedra, papel. tijera]: ")
#despues declaramos cuales son las opciones que pueden elegir
opciones = ["piedra", "papel", "tijera"]

#ahora declaramos que si los dos jugadores eligen la misma opcion, el resultado será un empate
if jugador1 == jugador2:
  print("empate")

#ahora declaramos las otras combinaciones que se pueden elegir y se imprime el resultado correspondiente dependiendo de cada opción
elif jugador1 == "piedra" and jugador2 == "papel":
  print("gana: jugador 2")
elif jugador1 == "piedra" and jugador2 == "tijera":
  print("gana: jugador 1")
elif jugador1 == "papel" and jugador2 == "piedra":
  print("gana: jugador 1")
elif jugador1 == "papel" and jugador2 == "tijera":
  print("gana: jugador 2")
elif jugador1 == "tijera" and jugador2 == "piedra":
  print("gana: jugador 2")
elif jugador1 == "tijera" and jugador2 == "papel":
  print("gana: jugador 1")
# Out:
# jugador 1: elija una opcion- [piedra, papel. tijera]: piedra
# jugador 2: elija una opcion- [piedra, papel. tijera]: papel
# gana: jugador 2

# %% [markdown]
# Ejercicio 3
#
# Implementar un programa que imprima el siguiente patron:
#
# 123456
#
# 12345
#
# 1234
#
# 123
#
# 12
#
# 1
#
# 12
#
# 123
#
# 1234
#
# 12345
#
# 123456

# %%
#primero declaramos la variable i que nos ayudará a mantener un control de los indices de nuestra lista
i=0
#declaramos los valores a imprimir ordenandolos en una lista
#indice:    0         1      2      3     4   5
lista = ["123456", "12345","1234","123","12","1"]

#hacemos un bucle while que imprima los elementos de la lista por su índice
while i < 6:
  print(lista[i])
  i = i + 1
  #cuando lleguemos al indice 5, la lista entrará en otro bucle while
  if i == 5:
  #en este bucle while, se disminuirá el indice de la lista hasta que lleguemos otra vez al índice 0
    while i >= 0:  
      print(lista[i])
      i = i-1
      if i < 0:
  #para que nuestro bucle while no siga infinitamente, declaramos un break cuando el índice llegue a 0
        break
    break
# Out:
# 123456
# 12345
# 1234
# 123
# 12
# 1
# 12
# 123
# 1234
# 12345
# 123456
