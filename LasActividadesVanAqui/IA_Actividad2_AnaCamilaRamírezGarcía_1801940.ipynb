# %% [markdown]
# Actividad 2
#
# Ejercicios Introducción Python
#
# Ana Camila Ramírez García 1801940
#
# Inteligencia Artificial y Redes Neuronales
#
# Martes N4

# %% [markdown]
# **Ejercicio 1:**
#
# Crear un programa que pregunte al usuario por su nombre, edad, una frase favorita y autor de la frase favorita. El programa deberá de imprimir un mensaje compuesto por el nombre y edad del usuario diciendo que su frase favorita es la que dió anteriormente y el autor de dicha frase es el nombre previamente dado. Aquí habrá que realizar una concatenación de variables.

# %%
# se piden los datos y se guardan en las variables con el respectivo nombre
name = input("¿cuál es su nombre?: ")
edad = input ("cual es su edad?: ")
frase = input ("cual es su frase favorita?: ")
autor = input("quien es el autor de su frase?: ")

#se hace la concatenacion de variables para crear el mensaje e imprimirlo
print("Nombre: " + name + " Edad: " + edad + " años"+ " Frase favorita: " + " <" + frase + "> " + " del autor: " + autor)
# Out:
# ¿cuál es su nombre?: Camila
# cual es su edad?: 21
# cual es su frase favorita?: La medida del amor es amar sin medida
# quien es el autor de su frase?: San Agustín
# Nombre: Camila Edad: 21 años Frase favorita:  <La medida del amor es amar sin medida>  del autor: San Agustín

# %% [markdown]
# **Ejercicio 2:**
#
# Crear un programa que le pida al usuario capturar dos números enteros y dos números flotantes. Después, realizará la suma, resta, multiplicación y división, de ambos pares de números. Como resultado se deberán de obtener 8 valores. Imprimir todos estos reultados.

# %%
# se piden los dos numeros enteros y los dos numeros flotantes y se guardan en las variables con el respectivo nombre
ent1 = int (input("Escribe el primer numero entero: ")) 
ent2 = int (input("Escribe el segundo numero entero: ")) 
flo1 = float (input("Escribe el primer numero flotante: ")) 
flo2 = float (input("Escribe el segundo numero flotante: ")) 

#se procede a hacer la suma, resta, multiplicación y división de ambos pares de numeros
suma1 = ent1 + ent2
suma2 = flo1 + flo2
resta1 = ent1 - ent2
resta2 = flo1 - flo2
mult1 = ent1 * ent2
mult2 = flo1 * flo2
div1 = ent1 / ent2
div2 = flo1 / flo2

#se procede a imprimir los resultados obtenidos
print("suma:")
print(suma1)
print(suma2)
print("resta:")
print(resta1)
print(resta2)
print("multiplicación:")
print(mult1)
print(mult2)
print("división:")
print(div1)
print(div2)
# Out:
# Escribe el primer numero entero: 2
# Escribe el segundo numero entero: 8
#  Escribe el primer numero flotante: 2.4
#  Escribe el segundo numero flotante: 2.6
# suma:
# 10
# 5.0
# resta:
# -6
# -0.20000000000000018
# multiplicación:
# 16
# 6.24
# división:
# 0.25
# 0.923076923076923

# %% [markdown]
# **Ejercicio 3:**
#
# Crear un programa que evalúe dos expresiones lógicas con `and`, dos con `or` y dos con `not`. Cada expresión deberá hacer uso de operadores de comparación.

# %%
#evaluar dos expresiones logicas usando <and>

print (3>5 and 4>2)
print (100>50 and 600>20)

#evaluar dos expresiones logicas usando <or>

print (34>50 or 20>20)
print (100>50 or 600>20)

#evaluar dos expresiones logicas usando <not>

print (not 12<40)
print (not 35<12)
# Out:
# False
# True
# False
# True
# False
# True
